# %%
from math import sqrt

# %%
def isPrime(n):
    if n <= 1:
        return False
    if n <= 3:
        return True
    if n % 2 == 0 or n % 3 == 0:
        return False
    i = 5
    while i * i <= n:
        if n % i == 0 or n % (i + 2) == 0:
            return False
        i += 6
    return True

# %%
def checkPrime(n):
    if isPrime(n):
        return 'Prime'
    else:
        return 'Not Prime'

# %%
def isPrime(n):
    for i in range (2, int(sqrt(n)+1) ):
        if n % i == 0:
            return False
    return True if n > 1 else False

# %%
def check_doxung(n):
    str2 = "".join(reversed(str(n)))
    if int(str2) == n:
        return True
    return False

# %%
x= 1221
def check_number(n):
    if check_doxung(n) and isPrime(n):
        return True
    else:
        return False

# %%
for i in range (1011):
    if check_number(i):
        print(f'{i} : {check_number(i)}')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n= int(input("số lượng: "))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import sqrt

# %%
def isPrime(n):
    for i in range (2, int(sqrt(n)+1)):
        if n% i==0:
            return False
    return True if n>=2 else False

# %%
def check_doiXung(n):
    n_temp = "".join(reversed(str(n)))
    return True if int(n_temp)==n else False

# %%
S= int(input("S= "))
E= int(input("E= "))
while not S<E:
    S= int(input("Nhập lại S= "))
    E= int(input("Nhập lại E= "))
else:
    print("Nhập đúng")
sum=0
for i in range (S, E+1):
    if isPrime(i) and check_doiXung(i):
        sum+=i
        print(f'{i} : {isPrime(i)}, {check_doiXung(i)}')
print(f"Tổng các số vừa nguyên tố vừa đối xứng: {sum}")

# %%
print('abcefd'.replace('cd', '12'))

# %%
[(2**x) for x in range(0, 13)]

# %%
[(x**2) for x in range(1, 13)]

# %%
[(2**x) for x in range(1, 13)]

# %%
[(x**2) for x in range(0, 13)]

# %%
print([i+j for i in "abc" for j in "def"])

# %%
names = ['Amir', 'Bear', 'Charlton', 'Daman']

print(names[-1][-1])

# %%
squares = {1:1, 2:4, 3:9, 4:16, 5:25}

print(squares.pop(4))
print(squares)

# %%
[(2**x) for x in range(1, 13)]
