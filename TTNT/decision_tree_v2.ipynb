# %%
import pandas as pd

# %%
df = df = pd.read_excel("/content/dulieu1.xlsx")
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4       Unnamed: 5
# 0         NaN          A          B          C          D            CLASS
# 1         NaN          7        3.2        4.7        1.4  Iris-versicolor
# 2         NaN        6.4        3.2        4.5        1.5  Iris-versicolor
# 3         NaN        6.9        3.1        4.9        1.5  Iris-versicolor
# 4         NaN        5.5        2.3          4        1.3  Iris-versicolor

# %%
inputs = df.drop(5,axis="columns")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-6555533f8588> in <cell line: 1>()
# ----> 1 inputs = df.drop(5,axis="columns")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
inputs
# Out:
# array([['A', 'B', 'C', 'D'],
#        [7, 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4, 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [6.3, 3.3, 6, 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3, 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3, 5.8, 2.2],
#        [7.6, 3, 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5]], dtype=object)

# %%
target = df.Drug

# %%
target
# Out:
# 0      drugY
# 1      drugC
# 2      drugC
# 3      drugX
# 4      drugY
#        ...
# 195    drugC
# 196    drugC
# 197    drugX
# 198    drugX
# 199    drugX
# Name: Drug, Length: 200, dtype: object

# %%
le_sex = LabelEncoder()
le_bp = LabelEncoder()
le_cholesterol = LabelEncoder()
le_drug = LabelEncoder()

# %%
inputs["Sex"] = le_sex.fit_transform(inputs["Sex"])
inputs["BP"] = le_bp.fit_transform(inputs["BP"])
inputs["Cholesterol"] = le_cholesterol.fit_transform(inputs["Cholesterol"])
target = le_drug.fit_transform(target)

# %%
target
# Out:
# array([4, 2, 2, 3, 4, 3, 4, 2, 4, 4, 2, 4, 4, 4, 3, 4, 3, 0, 2, 4, 4, 4,
#        4, 4, 4, 4, 4, 3, 4, 4, 3, 1, 3, 4, 3, 3, 0, 3, 3, 3, 4, 1, 4, 3,
#        3, 3, 0, 2, 4, 4, 4, 3, 4, 4, 1, 2, 1, 4, 3, 4, 4, 0, 4, 3, 1, 4,
#        0, 3, 4, 4, 1, 4, 3, 4, 4, 4, 0, 4, 0, 3, 1, 3, 2, 0, 2, 1, 3, 4,
#        4, 4, 4, 4, 4, 4, 4, 3, 4, 4, 4, 4, 0, 0, 2, 3, 4, 3, 3, 4, 1, 4,
#        0, 3, 3, 3, 3, 4, 3, 3, 0, 4, 4, 4, 4, 4, 1, 4, 4, 3, 4, 3, 4, 4,
#        3, 4, 4, 3, 1, 0, 1, 3, 0, 4, 1, 4, 0, 3, 3, 0, 3, 2, 0, 1, 3, 3,
#        4, 2, 0, 4, 2, 3, 3, 1, 3, 4, 4, 4, 4, 3, 4, 0, 3, 3, 4, 4, 0, 4,
#        0, 4, 4, 4, 4, 3, 3, 4, 4, 4, 1, 0, 4, 4, 4, 0, 4, 2, 4, 2, 2, 3,
#        3, 3])

# %%
X_train,X_test,y_train,y_test = train_test_split(inputs,target,test_size=0.2)

# %%
X_train
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K
# 198   23    1   2            1   14.020
# 65    68    0   2            1   27.050
# 89    50    0   2            1   17.211
# 167   57    0   2            0   14.216
# 107   42    1   1            0   20.013
# ..   ...  ...  ..          ...      ...
# 4     61    0   1            0   18.043
# 191   23    1   0            0    8.011
# 125   19    0   0            1   25.969
# 52    62    1   1            1   27.183
# 151   68    1   0            0   11.009
#
# [160 rows x 5 columns]

# %%
y_train
# Out:
# 169    drugA
# 4      drugY
# 167    drugX
# 42     drugY
# 79     drugX
#        ...
# 117    drugX
# 109    drugY
# 144    drugA
# 72     drugX
# 111    drugX
# Name: Drug, Length: 160, dtype: object

# %%
model_entropy = DecisionTreeClassifier(criterion="entropy")

# %%
model_entropy.fit(X_train.values,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = model_entropy.predict(X_test)

# %%
col_y_pred = pd.DataFrame(y_pred,columns=["pred"])
col_y_pred
# Out:
#     pred
# 0      4
# 1      4
# 2      2
# 3      4
# 4      4
# 5      4
# 6      3
# 7      1
# 8      3
# 9      3
# 10     4
# 11     3
# 12     3
# 13     4
# 14     4
# 15     0
# 16     4
# 17     4
# 18     4
# 19     3
# 20     1
# 21     2
# 22     4
# 23     4
# 24     3
# 25     3
# 26     4
# 27     4
# 28     4
# 29     4
# 30     3
# 31     3
# 32     4
# 33     4
# 34     2
# 35     0
# 36     2
# 37     3
# 38     4
# 39     0

# %%
X_test.reset_index(drop=True, inplace=True)
col_y_pred.reset_index(drop=True, inplace=True)

# %%
pd.concat([X_test,col_y_pred],axis=1)
# Out:
#     Age  Sex  BP  Cholesterol  Na_to_K  pred
# 0    67    0   2            0   15.891     4
# 1    18    0   0            0   37.188     4
# 2    47    1   1            0   13.093     2
# 3    50    1   2            1   15.790     4
# 4    25    1   2            0   19.011     4
# 5    65    1   0            1   34.997     4
# 6    49    0   2            1    9.381     3
# 7    53    0   0            1   12.495     1
# 8    40    0   1            1   11.349     3
# 9    61    1   2            0    9.443     3
# 10   37    0   0            1   23.091     4
# 11   20    0   2            1    9.281     3
# 12   20    0   1            1   11.686     3
# 13   23    1   2            0   16.850     4
# 14   54    1   2            0   24.658     4
# 15   29    1   0            0   12.856     0
# 16   41    1   0            1   15.156     4
# 17   23    1   2            0   31.686     4
# 18   22    1   0            1   28.294     4
# 19   28    0   2            0   12.879     3
# ...

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
# Function to plot the decision tree
def plot_decision_tree(clf_object):
    plt.figure(figsize=(15, 10))
    plot_tree(clf_object,rounded=True,label="all")
    plt.show()

# %%
# plot_decision_tree(model_entropy)
model_entropy.predict([[67,0,2,0,15.891]])
# Out:
# array([4])
